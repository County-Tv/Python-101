# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Elif%20input%20and%20else%20statement%20for%20loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ELIF , INPUT , FOR LOOP

# %%
House = input("What is the color of your house: ")
Word = 1
for Name in House:
  if House == "Purple":
    print("we dont have that house either")
    Word +=1
  if House == "Yellow":
    print("we dont have that color")
    Word +=1
  if House == "Green":
    print("the color you chose letter",Name, "is the", Word , "letter")
    Word += 1
else:
  print("what color are you looking for")
# Out:
# What is the color of your house: Purple
# we dont have that house either
# we dont have that house either
# we dont have that house either
# we dont have that house either
# we dont have that house either
# we dont have that house either
# what color are you looking for
