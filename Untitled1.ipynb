# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Getting users unput

# %%
Age = float(input("what is your age: "))
print ("Your age is: " ,Age)
# Out:
# what is your age: 25
# Your age is:  25.0

# %%
print("Wait ah minute how old are you")
Age = input(float())
if Age == '25':
    print ("Did you sexperience quater life crisis")
elif Age < '30':
    print("ok You are almost marrying age")
else:
    print("OK you just old")
# Out:
# Wait ah minute how old are you
# 0.060
# OK you just old

# %%
def DoAdd (Value1,Value2):
  return Value1 + Value2

# %%
print("The sum of 3 + 4 is", DoAdd(3,4) == DoAdd(2,5))
# Out:
# The sum of 3 + 4 is True

# %%
print("What is your name")
Name = input()
if Name=='Harry':
  print("whats up harry")
elif Name=='Thomas':
  print("Yo Thomas")
else:
  print("Who are you")
# Out:
# What is your name
# sean
# Who are you

# %% [markdown]
# ## Making Decisions

# %%
TestMe = 6
if TestMe == 6:
  print("TestMe equals 6")
# Out:
# TestMe equals 6

# %%
TestMe == 8
# Out:
# False

# %%
TestMe = 6
if TestMe == 6:
  print("TestMe equals 6")
  print("All done")
# Out:
# TestMe equals 6
# All done

# %%
Value = int(input("Type a number bertween 1 and 10: " ))
if (Value > 0) and (Value <= 10):
    print("You typed: ", Value)
else:
    print("We Dont Know What This Is")
# Out:
# Type a number bertween 1 and 10: 18
# We Dont Know What This Is

# %%
print("1. Red")
print("2. Orange")
print("3. Yellow")
print("4. Green")
print("5. Blue")
print("6. Purple")
Choice = int(input("Select your favorite color: "))
if Choice == 1:
    print("You chose Red")
elif Choice == 2:
    print("You chose Orange")
elif Choice == 3:
    print("You chose Yellow")
elif Choice == 4:
    print("You Chose Green")
elif Choice == 5:
    print("You Chose Blue")
elif Choice == 6:
    print("You Chose Purple")
else:
    print("You made an invalid choice")
# Out:
# 1. Red
# 2. Orange
# 3. Yellow
# 4. Green
# 5. Blue
# 6. Purple
# Select your favorite color: 9
# You made an invalid choice

# %% [markdown]
# # Using Multiple if or elif statements

# %%
One = int(input("Type a number between 1 and 10:"))
Two = int(input("Type a number between 1 and 10:"))
if (One >= 1) and (One <=10):
    if (Two >=1) and (Two <=10):
      print("Your magic number is: ", One * Two)
    else:
      print("Incorrect second number")
else:
    print("Incorrect first number")
# Out:
# Type a number between 1 and 10:11
# Type a number between 1 and 10:2
# Incorrect first number

# %% [markdown]
# # Nesting LOOP

# %%
print("1. NY")
print("2. NJ")
print("3. CT")
print("4. PA")
State = int(input("what state are your from: "))
if State == 1:
  Accent = "New York"
  print(" your accent is", Accent)
elif State == 2:
  Accent = "New Jersey"
  print(" your accent is", Accent)
elif State == 3:
  Accent = "Connecticut"
  print(" your accent is", Accent)
elif State == 4:
  Accent = "Pennsylvania"
  print(" your accent is", Accent)
elif State == 7:
  Accent = "Unknown"
  print("Can you clarify which artist lives in your state?")
  Artist = int(input("what state are your from: "))
  print("1. Flo rida")
  print("2. Beyonce")
  print("3. Tyga")
  print("4. Kanye ")
  if Artist == 2:
     Location = "Texas"
     print("Beyonce is a good artist coming straight out of", Location)
  elif Artist == 3:
     Location = "Cali"
     print("Tyga is a good artist coming straight out of", Location)
  elif Artist == 4:
     Location = "Chicago"
     print("Kanye is a good artist coming straight out of", Location)
  elif Artist == 1:
     Location = "Florida"
     print("Flo is a good artist coming straight out of", Location)
  else:
     Location = "Unknown"
     print("Can you clarify which artist lives in your state?")
# Out:
# 1. NY
# 2. NJ
# 3. CT
# 4. PA
# what state are your from: 7
# Can you clarify which artist lives in your state?
# what state are your from: 2
# 1. Flo rida
# 2. Beyonce
# 3. Tyga
# 4. Kanye
# Beyonce is a good artist coming straight out of Texas
