# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Input%20%2B%20IF%20/%20ELSE%20statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Making Decisions

# %%
Name = input("what is your name:  ")
if Name == "Khris":
  print("your name is: ", Name)
else:
  print("wrong name")
# Out:
# what is your name:  Khris
# your name is:  Khris
