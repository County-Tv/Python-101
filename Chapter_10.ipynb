# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Chapter_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Channel = 1
for C in "County", "Tech" , "View":
  print(" You have" , Channel , "in" , C)
  Channel +=1
# Out:
#  You have 1 in County
#  You have 2 in Tech
#  You have 3 in View

# %%
Value = input("Enter a six character movie: ")
Movies = 1
for M in "Movies":
  print( "Thats", Movies, "in" ,M)
  Movies+=1
  if Movies > 6:
    print("The List is to long")
    break
# Out:
# Enter a six character movie: ok
# Thats 1 in M
# Thats 2 in o
# Thats 3 in v
# Thats 4 in i
# Thats 5 in e
# Thats 6 in s
# The List is to long
