# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Defininf%20a%20function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# # Defining A Function

# %%
def Daysofweek():
  print("MTWTF")

# %%
Daysofweek()
# Out:
# MTWTF

# %%
def daysofmonth(JFMAMJJASAND):
  print(JFMAMJJASAND)

# %%
daysofmonth()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2593068586.py in <cell line: 0>()
# ----> 1 daysofmonth()
#
# TypeError: daysofmonth() missing 1 required positional argument: 'JFMAMJJASAND'

# %%
daysofmonth("5 + 5")
daysofmonth("JFMAMJJASAND")
print(daysofmonth)
# Out:
# 5 + 5
# JFMAMJJASAND
# <function daysofmonth at 0x7ecb3d6f7b00>
