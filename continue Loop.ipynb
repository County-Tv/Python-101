# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/continue%20Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
Count = 1
for C in "Counting":
  if C == "n":
    continue
  print("We need to count by", Count, " to get", C)
  Count += 1
# Out:
# We need to count by 1  to get C
# We need to count by 2  to get o
# We need to count by 3  to get u
# We need to count by 4  to get t
# We need to count by 5  to get i
# We need to count by 6  to get g
