# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/For%20loops%20test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # For Loops

# %%
Castle = 1
for House in "Mansion":
  print("The letter",House,"in Mansion is",Castle)
  Castle +=1
# Out:
# The letter M in Mansion is 1
# The letter a in Mansion is 2
# The letter n in Mansion is 3
# The letter s in Mansion is 4
# The letter i in Mansion is 5
# The letter o in Mansion is 6
# The letter n in Mansion is 7
