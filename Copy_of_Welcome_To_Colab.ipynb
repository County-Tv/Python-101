# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Chapter 7

# %%
  print("containers in AWS:")
  Containers=input()
if Containers == '3':
   print("storage is low")
elif Containers =='7':
    print("storage is just right")
else:
    print("storage does not fit range")
# Out:
# containers in AWS:
# 3
# storage is low
