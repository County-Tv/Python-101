# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Using if statement in an *opperation*

# %%
Testme = 6
if Testme == 6:
  print("wow , thats amazing")
# Out:
# wow , thats amazing

# %%
print("what is your favorite food , we have the following")
print("1.Burgers")
print("2.sandwich")
print("3.sphagetti")
print("4.salads")
Mainchoice = int(input("what is your choice of meal:", ))
if Mainchoice == 1:
  Meal = "Burgers"
if Mainchoice == 2:
  Meal = "Sandwich"
elif Mainchoice == 3:
  Meal = "Sphagetti"
elif Mainchoice == 4:
  print("what would you like with the salad")
  print("1.tamatoes")
  print("2.walnuts")
  print("3.grapes")
  Salad = int(input())
  if Salad == 1:
    choice  = "tamatoes"
    print("That salad does taste good with", choice)
  elif Salad == 2:
    choice = "Walnuts"
    print("That salad does taste good with", choice)
  elif Salad == 3:
    choice = "Grapes"
    print("That salad does taste good with", choice)
  else:
    print("we dont have that try a different resturant")
if (Mainchoice == 1) or ( Mainchoice == 2) or (Mainchoice == 3):
  print("You chose", Meal , "with fries")
else:
  print("we dont have anything like that here")
# Out:
# what is your favorite food , we have the following
# 1.Burgers
# 2.sandwich
# 3.sphagetti
# 4.salads
# what is your choice of meal:3
# You chose Sphagetti with fries
