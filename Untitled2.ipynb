# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Using if statement in an *opperation*

# %%
Testme = 6
if Testme == 6:
  print("wow , thats amazing")
# Out:
# wow , thats amazing

# %%
Value = int(input("Tell Me a Value Between 1 and 10: "))
if (Value > 0) and (Value <=10):
  print("You are in a good range")
else:
  print("You are not in a good range")
# Out:
# Tell Me a Value Between 1 and 10: 8
# You are in a good range

# %%
six = int(input("Tell me of a value between 1 and 10: "))
one = int(input("Tell me of a value between 1 and 10: "))
if (six > 0 ) and ( six <=10):
  if (one > 0) and (one <= 10):
   print("you choose the right value")
  else:
    print("your number one is out of range")
else:
    print("Number six is out of range")
# Out:
# Tell me of a value between 1 and 10: 11
# Tell me of a value between 1 and 10: 2
# Number six is out of range

# %%
print("1.eggs")
print("2.Salad")
print("3.waffles")
print("4.oatmeal")
Mainchoice = int(input("what would you like to eat: "))
if (Mainchoice == 1 ):
  Meal = "eggs"
if (Mainchoice == 2):
  Meal = "Salad"
if (Mainchoice == 3):
  print("what do you want on your waffles: ")
  print("syrup")
  print("BlueBerries")
  print("whoopcream")
  toppings = int(input())
  if (toppings == 1):
    print("you chose syrup with your toppings")
  if (toppings == 2):
    print("you chose Blueberries with your toppings")
  if(toppings == 3):
     print("you choose whoopcream with your toppings")
  else:
    print("that topping is unavailiable")
if ( Mainchoice == 1 ) or (Mainchoice ==2 ):
  print("what else do you want with your:", Meal)
if(Mainchoice == 4):
  print("Just oatmeal ok than")
else:
  (" sorry we dont have that")
# Out:
# 1.eggs
# 2.Salad
# 3.waffles
# 4.oatmeal
# what would you like to eat: 2
# what else do you want with your: Salad
