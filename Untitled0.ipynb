# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def addsomething(value1,value2):
  return value1 + value2

print(addsomething(1,2))
# Out:
# 3

# %% [markdown]
# #Parent Heading

# %% [markdown]
# ## Child heading

# %%
Name = input("What is the name of your chanel: ")
print(f"Your chanel name is:  {Name}")
# Out:
# What is the name of your chanel: County Tech View
# Your chanel name is:  County Tech View

# %%
print("Thanks For Watching my chanel"
      + " Come back Later" )
# Out:
# Thanks For Watching my chanel Come back Later
