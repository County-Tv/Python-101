# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Continue%20Clause.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Continue Clause

# %%
LetterNum = 1
for Letter in "Howdy!":
  if Letter == "w":
    continue
    print("Encoutered w, not processed.")
  print("Letter", LetterNum,"is",Letter)
  LetterNum += 1
# Out:
# Letter 1 is H
# Letter 2 is o
# Letter 3 is d
# Letter 4 is y
# Letter 5 is !
