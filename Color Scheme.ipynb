# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Color%20Scheme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Making Decisions and User Input

# %%
Name = input("what is your name:  ")
if Name == "Khris":
  print("your name is: ", Name)
else:
  print("wrong name")
# Out:
# what is your name:  Khris
# your name is:  Khris

# %%
Value = int(input("what is your age: "))
if (Value > 0 ) and (Value <= 10):
  print("This person is: ", Value,"Years old")
else:
  print("The age is undefined")
# Out:
# what is your age: 11
# The age is undefined

# %%
print("1.red")
print("2.orange")
print("3.purple")
print("4.blue")
print("5.brown")
Color = input("what is your favorite color: ")
if Color == "Red":
  print("That is a fire color")
elif Color == "Orange":
    print("thats a mixture between two colors")
elif Color == "Purple":
    print("thats a grape idea")
elif Color == "Brown":
    print("bring it a brown town")
elif Color == "Blue":
    print("im blue dottle dee dottle daa")
else:
  print("we aint got that color")
# Out:
# 1.red
# 2.orange
# 3.purple
# 4.blue
# 5.brown
# what is your favorite color: yellow
# we aint got that color
