# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python 101

# %%
Coding = input("what is your first coding language: ")
print (f"Your first coding style is: {Coding}")
# Out:
# what is your first coding language: Python
# Your first coding style is: Python

# %%
House =  1 > 2
print (House)
# Out:
# False

# %%
Team = str("catch me outside  with no one ," + " how about that")
print (Team)
# Out:
# catch me outside  with no one , how about that

# %%
" Hello " if True else "Goodbye"
# Out:
# ' Hello '

# %%
+4
# Out:
# 4

# %%
~4
# Out:
# -5

# %%
-4
# Out:
# -4

# %%
1 == 2
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
X = 31
A = 56
print (A + X )
# Out:
# 87

# %%
"Test" in "Test in 123"
# Out:
# True

# %%
"Goodwork" in "Good working"
# Out:
# False

# %%
"Truth" in "Truthing"
# Out:
# True

# %%
type(2) is int
# Out:
# True
