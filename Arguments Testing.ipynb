# %% [markdown]
# <a href="https://colab.research.google.com/github/County-Tv/Python-101/blob/master/Arguments%20Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arguments

# %%
def AddIt(Value1, Value2):
  print(Value1,"+", Value2, "=",(Value1 + Value2))

# %%
AddIt(3,2)
# Out:
# 3 + 2 = 5

# %%
def Hello3(Greeting = "No Value supplied"):
  print(Greeting)

# %%
Hello3("this is a string")
# Out:
# this is a string

# %%
Hello3(5)
Hello3(2+7)
Hello3()
# Out:
# 5
# 9
# No Value supplied

# %%
def Hello4(ArgCount, *VarArgs):
  print("You passed" , ArgCount, "arguments.")
  for Arg in VarArgs:
    print(Arg)

# %%
Hello4(1, "A Test String")
# Out:
# You passed 1 arguments.
# A Test String

# %%
Hello4(4,"one", "two", "three", "four")
# Out:
# You passed 4 arguments.
# one
# two
# three
# four

# %%
def DoAdd(Value1 , Value2):
  return Value1 + Value2

# %%
DoAdd(5,6)
# Out:
# 11
